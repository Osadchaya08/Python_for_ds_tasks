# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
data = pd.read_csv('/Users/applebuy/Downloads/data_statistics/data.csv')

# %%
data.shape
# Out:
# (100, 2)

# %%
data = df.iloc[:, 0].values

# %%
mean = np.mean(data)
std = np.std(data)

# Generate x-axis values for the PDF
x_axis = np.arange(data.min(), data.max(), 0.01)

# Plot normalized histogram of the data
plt.hist(data, bins=10, density=True)

# Plot the PDF of the normal distribution
plt.plot(x_axis, norm.pdf(x_axis, mean, std), color='red', lw=2)

plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Data Distribution and Normal Distribution PDF')

# Show the plot
plt.show()

# %%
# На мою думку дані розподілені нормально, так як форма нормованої гістограми добре відповідає формі теоретичної функції щільності.

# %%
from scipy.stats import probplot
from statsmodels.stats.weightstats import ztest

# %%
data = df.iloc[:,1].values

probplot(data, dist="norm", plot=plt)
plt.title('Q-Q Графік Q-Q для перевірки нормальності')
plt.xlabel('Теоретичні квантилі')
plt.ylabel('Зразкові квантилі')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# На мою думку дані розподілені нормально. Присутні на кінцях відхилення, але вони не значні.
